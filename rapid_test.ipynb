# %%
import numpy as np
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.0'

# %%
np.__version__
# Out:
# '1.26.3'

# %%
df=pd.DataFrame(columns= ['ID','Name','City','Salary','Job'])
df
# Out:
# Empty DataFrame
# Columns: [ID, Name, City, Salary, Job]
# Index: []

# %%
sub_df=pd.Series(['100','Anil','10000','Python developer'])

# %%
sub_df
# Out:
# 0                 100
# 1                Anil
# 2               10000
# 3    Python developer
# dtype: object

# %%
df= pd.read_html(r'https://www.worldometers.info/coronavirus/country/us/')

# %%
df=df[0]

# %%
df
# Out:
#        #              USA State  Total Cases  New Cases  Total Deaths  \
# 0    NaN              USA Total    110818155        NaN     1194100.0
# 1    1.0             California     12571376        NaN      106559.0
# 2    2.0                  Texas      9030821        NaN       95747.0
# 3    3.0                Florida      7943053        NaN       93076.0
# 4    4.0               New York      7504781        NaN       82367.0
# ..   ...                    ...          ...        ...           ...
# 60  60.0        Federal Prisons        71485        NaN         324.0
# 61  61.0    Grand Princess Ship          122        NaN           7.0
# 62  62.0      Wuhan Repatriated            3        NaN           NaN
# 63  63.0  Diamond Princess Ship           46        NaN           NaN
# 64   NaN                 Total:    110818155        NaN     1194100.0
#
#     New Deaths  Total Recovered  Active Cases  Tot Cases/ 1M pop  \
# ...

# %%
main_df= pd.DataFrame(columns=(df.columns[1:]).insert(0,['Continent']) )

# %%
main_df=main_df.drop(columns=df.columns[6:])

# %%
for index, row in df.iterrows():
    print(type(row.to_list()))
    line_item=row.to_list()
    print(line_item)
    if line_item[1].startswith('U'): #if line item is not numberassign this value to continent 
        continent='USA'
        print('Yes')
    else:
        continent= ''
    mini_df=pd.DataFrame([{'Continent':continent, df.columns[1]:line_item[1],df.columns[2]:line_item[2],df.columns[3]:line_item[3],df.columns[4]:line_item[4],df.columns[5]:line_item[5]}])
    main_df= pd.concat([main_df,mini_df])
# Out:
# <class 'list'>
# [nan, 'USA Total', 110818155, nan, 1194100.0, nan, 108527715.0, 1096340.0, 334884.0, 3608.0, 1186624369.0, 3585888.0, nan, nan, nan]
# Yes
# <class 'list'>
# [1.0, 'California', 12571376, nan, 106559.0, nan, 12454971.0, 9846.0, 318164.0, 2697.0, 202799362.0, 5132573.0, 39512223.0, '[1]', '[projections]']
# <class 'list'>
# [2.0, 'Texas', 9030821, nan, 95747.0, nan, 8891047.0, 44027.0, 311452.0, 3302.0, 73904384.0, 2548789.0, 28995881.0, '[1]', '[projections]']
# <class 'list'>
# [3.0, 'Florida', 7943053, nan, 93076.0, nan, 7797846.0, 52131.0, 369827.0, 4334.0, 66800091.0, 3110202.0, 21477737.0, '[1]', '[projections]']
# <class 'list'>
# [4.0, 'New York', 7504781, nan, 82367.0, nan, 7390422.0, 31992.0, 385779.0, 4234.0, 131503719.0, 6759879.0, 19453561.0, '[1]\xa0[2]', '[projections]']
# <class 'list'>
# [5.0, 'Illinois', 4136659, nan, 42005.0, nan, 4094654.0, 0.0, 326446.0, 3315.0, 57898053.0, 4569040.0, 12671821.0, '[1]', '[projections]']
# <class 'list'>
# ...

# %%
main_df
# Out:
# Empty DataFrame
# Columns: [Continent, USA State, Total Cases, New Cases, Total Deaths, New Deaths]
# Index: []

# %%
{'Continent':'', df.columns[0]:line_item[0],df.columns[1]:line_item[1],df.columns[2]:line_item[2],df.columns[3]:line_item[3],df.columns[4]:line_item[4]}
# Out:
# {'Continent': '',
#  '#': nan,
#  'USA State': 'USA Total',
#  'Total Cases': 110818155,
#  'New Cases': nan,
#  'Total Deaths': 1194100.0}

# %%
mini_df
# Out:
#   Continent  USA State  Total Cases  New Cases  Total Deaths  New Deaths
# 0            USA Total    110818155        NaN     1194100.0         NaN

# %%
pd.concat([main_df,mini_df])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_7048\376976551.py:1: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pd.concat([main_df,mini_df])
#   Continent  USA State Total Cases  New Cases  Total Deaths  New Deaths
# 0            USA Total   110818155        NaN     1194100.0         NaN

# %%
main_df
# Out:
#    Continent              USA State Total Cases  New Cases  Total Deaths  \
# 0                         USA Total   110818155        NaN     1194100.0
# 0                        California    12571376        NaN      106559.0
# 0                             Texas     9030821        NaN       95747.0
# 0                           Florida     7943053        NaN       93076.0
# 0                          New York     7504781        NaN       82367.0
# ..       ...                    ...         ...        ...           ...
# 0                   Federal Prisons       71485        NaN         324.0
# 0               Grand Princess Ship         122        NaN           7.0
# 0                 Wuhan Repatriated           3        NaN           NaN
# 0             Diamond Princess Ship          46        NaN           NaN
# 0                            Total:   110818155        NaN     1194100.0
#
#     New Deaths
# 0          NaN
# 0          NaN
# 0          NaN
# 0          NaN
# ...

# %%
mini_df
# Out:
#   Continent  USA State  Total Cases  New Cases  Total Deaths  New Deaths
# 0       USA  USA Total    110818155        NaN     1194100.0         NaN

# %%
main_df
# Out:
#    Continent              USA State Total Cases  New Cases  Total Deaths  \
# 0                         USA Total   110818155        NaN     1194100.0
# 0                        California    12571376        NaN      106559.0
# 0                             Texas     9030821        NaN       95747.0
# 0                           Florida     7943053        NaN       93076.0
# 0                          New York     7504781        NaN       82367.0
# ..       ...                    ...         ...        ...           ...
# 0               Grand Princess Ship         122        NaN           7.0
# 0                 Wuhan Repatriated           3        NaN           NaN
# 0             Diamond Princess Ship          46        NaN           NaN
# 0                            Total:   110818155        NaN     1194100.0
# 0        USA              USA Total   110818155        NaN     1194100.0
#
#     New Deaths
# 0          NaN
# 0          NaN
# 0          NaN
# 0          NaN
# ...

# %%
main_df= main_df.dropna()

# %%
main_df
# Out:
# Empty DataFrame
# Columns: [Continent, USA State, Total Cases, New Cases, Total Deaths, New Deaths]
# Index: []

# %%
main_df.reset_index().drop(columns=['index'])
# Out:
#    Continent              USA State Total Cases  New Cases  Total Deaths  \
# 0        USA              USA Total   110818155        NaN     1194100.0
# 1        USA              USA Total   110818155        NaN     1194100.0
# 2                        California    12571376        NaN      106559.0
# 3                             Texas     9030821        NaN       95747.0
# 4                           Florida     7943053        NaN       93076.0
# ..       ...                    ...         ...        ...           ...
# 61                  Federal Prisons       71485        NaN         324.0
# 62              Grand Princess Ship         122        NaN           7.0
# 63                Wuhan Repatriated           3        NaN           NaN
# 64            Diamond Princess Ship          46        NaN           NaN
# 65                           Total:   110818155        NaN     1194100.0
#
#     New Deaths
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# ...

# %%
# Out:
# Continent
#        61
# USA     5
# Name: count, dtype: int64
